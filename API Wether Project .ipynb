# %%
import pandas as pd
import requests

# %% [markdown]
# ### Maharashtra cities data from Weather Api

# %%
import requests
import pandas as pd 

# List of cities from various talukas/cities in Maharashtra

city_name = ['Mumbai', 'Andheri', 'Borivali', 'Pune', 'Pimpri-Chinchwad', 'Haveli', 
             'Mulshi', 'Khed', 'Aundh', 'Junnar', 'Nagpur', 'Kamptee', 'Narkhed', 
             'Umred', 'Saoner', 'Nashik', 'Nandgaon', 'Dindori', 'Trimbak', 'Igatpuri', 
             'Aurangabad', 'Jalna', 'Paithan', 'Sillod', 'Kannad', 'Kolhapur', 'Shirol',
             'Solapur', 'Barshi', 'Karmala', 'Pandharpur', 'Thane', 'Kalyan', 'Ulhasnagar',
             'Ambernath', 'Badlapur', 'Bhiwandi', 'Satara', 'Karad', 'Khatav', 'Wai', 
             'Phaltan', 'Sawantwadi', 'Kudal', 'Malvan', 'Vengurla', 'Chandrapur',
             'Ballarpur', 'Warora', 'Rajura', 'Beed', 'Patoda', 'Georai', 'Kaij', 
             'Ashti', 'Latur', 'Ausa', 'Nilanga', 'Malkapur', 'Chikhli', 'Khamgaon', 
             'Shegaon', 'Jalgaon Jamod', 'Jalna', 'Badnapur', 'Partur', 'Mantha', 
             'Ratnagiri', 'Chiplun', 'Dapoli', 'Rajapur', 'Khed', 'Hingoli', 
             'Kalamnuri', 'Wardha', 'Arvi', 'Deoli', 'Karanja', 
             'Yavatmal', 'Pusad', 'Arni', 'Wani', 'Digras', 'Akola', 'Patur', 
             'Telhara', 'Amravati', 'Morshi', 'Chandur Bazar', 'Achalpur',
             'Nandgaon Khandeshwar', 'Alibag', 'Uran', 'Panvel', 'Karjat', 'Khalapur', 
             'Washim', 'Khamgaon', 'Manora', 'Pusad']

    
API_Key="1be6fe3a073779145b4ccfa2dad856ec"

# List to hold all weather data
weather_data_list = []

# Fetch data for each city
for city in city_name:
    try:
        Req=requests.get("https://api.openweathermap.org/data/2.5/weather?q={}&appid=1be6fe3a073779145b4ccfa2dad856ec&units=metric"
.format(city))
        if Req.status_code == 200:
            data = Req.json()

            # Extract relevant weather data
            weather_data = {
                "City": data["name"],
                "Temperature (°C)": data["main"]["temp"],
                "Min_Temperature (°C)": data["main"]["temp_min"],
                "Max_Temperature (°C)": data["main"]["temp_max"],
                "Feels_Like (°C)": data["main"]["feels_like"],
                "Pressure (hpa)": data["main"]["pressure"],
                "Weather": data["weather"][0]["description"],
                "Humidity (%)": data["main"]["humidity"],
                "Wind Speed (m/s)": data["wind"]["speed"],
                "TimeZone (sec)": data["timezone"]
            }
            
            # Add the weather data for the current city to the list
            weather_data_list.append(weather_data)
        else:
             print(f"Error: Could not fetch data for {city}")
    except Exception as e:
        print(f"An error occurred while fetching data for {city}: {e}")

                                    
df = pd.DataFrame(weather_data_list) # Convert the list of weather data to a DataFrame
print(df)

# Save the DataFrame to a CSV file
df.to_csv("maharashtra_weather_data3.csv", index=False)
# Out:
#                 City  Temperature (°C)  Min_Temperature (°C)  \
# 0             Mumbai             30.99                 28.94
# 1            Andheri             20.76                 20.76
# 2           Borivali             28.90                 28.90
# 3               Pune             29.02                 29.02
# 4   Pimpri-Chinchwad             28.79                 28.79
# ..               ...               ...                   ...
# 95          Khalapur             32.07                 32.07
# 96            Wāshīm             27.42                 27.42
# 97          Khāmgaon             28.33                 28.33
# 98            Manora             27.43                 27.43
# 99             Pusad             27.89                 27.89
#
#     Max_Temperature (°C)  Feels_Like (°C)  Pressure (hpa)           Weather  \
# 0                  30.99            29.72            1010             smoke
# 1                  20.76            19.75            1013         clear sky
# ...
